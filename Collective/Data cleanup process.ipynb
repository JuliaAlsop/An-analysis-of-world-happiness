# %% [markdown]
# * **Step 1: A look into collective happiness for the Top 50 Happiest Countries in the World by Region

# %%
## Import Dependencies
import matplotlib.pyplot as plt
import sklearn.datasets as dta
from scipy.stats import linregress
import pandas as pd
import scipy.stats as sts
import numpy as np
import random
import math as math
import seaborn as sns
import os

# %%
## Create Data file Paths to open World Happiness Report, 2017 
whr_2017_path = "../World_Happiness_Reports/2017.csv"
region_data_path = "Region_Data.csv"

## Read WHR and region data, to find out what the top 50 countries are:
whr_2017_df = pd.read_csv(whr_2017_path)
region_data_df = pd.read_csv(region_data_path)

## Display the data table for preview
whr_2017_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
## Then Sort and selected top 50 countries: 
top_50_sorted_df = whr_2017_df.sort_values("Happiness.Rank", ascending=True).head(50)

## Write data to CSV
#top_50_sorted_df.to_csv('Top_50_Carolina.csv')

## Display the data table for preview
#top_50_sorted_df.head()

# %%
## Use merge function to combine the top 50 happiness countries and regions into a single dataset:
merged_countries_regions_df = pd.merge(top_50_sorted_df, region_data_df, left_on="Country", right_on="name")

## Write data to CSV
#merged_countries_regions_df.to_csv('merged_countries_regions.csv')

## Display the data table for preview
merged_countries_regions_df.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
# 5                  1.503945  1.428939                  0.810696  0.585384
# 6                  1.479204  1.481349                  0.834558  0.611101
# 7                  1.405706  1.548195                  0.816760  0.614062
# 8                  1.494387  1.478162                  0.830875  0.612924
# 9                  1.484415  1.510042                  0.843887  0.601607
#
#    Generosity  ...  alpha-2  alpha-3 country-code     iso_3166-2    region  \
# 0    0.362012  ...       NO      NOR          578  ISO 3166-2:NO    Europe
# 1    0.355280  ...       DK      DNK          208  ISO 3166-2:DK    Europe
# 2    0.475540  ...       IS      ISL          352  ISO 3166-2:IS    Europe
# 3    0.290549  ...       CH      CHE          756  ISO 3166-2:CH    Europe
# 4    0.245483  ...       FI      FIN          246  ISO 3166-2:FI    Europe
# 5    0.470490  ...       NL      NLD          528  ISO 3166-2:NL    Europe
# 6    0.435540  ...       CA      CAN          124  ISO 3166-2:CA  Americas
# 7    0.500005  ...       NZ      NZL          554  ISO 3166-2:NZ   Oceania
# 8    0.385399  ...       SE      SWE          752  ISO 3166-2:SE    Europe
# 9    0.477699  ...       AU      AUS           36  ISO 3166-2:AU   Oceania
#
#                   sub-region intermediate-region region-code sub-region-code  \
# 0            Northern Europe                 NaN       150.0           154.0
# 1            Northern Europe                 NaN       150.0           154.0
# 2            Northern Europe                 NaN       150.0           154.0
# 3             Western Europe                 NaN       150.0           155.0
# 4            Northern Europe                 NaN       150.0           154.0
# 5             Western Europe                 NaN       150.0           155.0
# 6           Northern America                 NaN        19.0            21.0
# 7  Australia and New Zealand                 NaN         9.0            53.0
# 8            Northern Europe                 NaN       150.0           154.0
# 9  Australia and New Zealand                 NaN         9.0            53.0
#
#   intermediate-region-code
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# In order to group countries into regions:

# %%
## Drop countries 
clean_df = merged_countries_regions_df.drop(['Country'], axis=1)

## Using GroupBy Sub Region
grouped_regions_df = clean_df.groupby(['sub-region']).mean()

## Write data to CSV
#grouped_regions_df.to_csv('grouped_regions_df.csv')

## Rename Index Column
grouped_regions_df.index.name = 'Region'

## Display
grouped_regions_df.head(5)
# Out:
#                                  Happiness.Rank  Happiness.Score  \
# Region
# Australia and New Zealand              9.000000         7.299000
# Central Asia                          47.000000         5.971000
# Eastern Asia                          33.000000         6.422000
# Eastern Europe                        39.500000         6.160750
# Latin America and the Caribbean       31.857143         6.390429
#
#                                  Whisker.high  Whisker.low  \
# Region
# Australia and New Zealand            7.368081     7.229919
# Central Asia                         6.065538     5.876463
# Eastern Asia                         6.494596     6.349404
# Eastern Europe                       6.236349     6.085152
# Latin America and the Caribbean      6.506846     6.274011
#
#                                  Economy..GDP.per.Capita.    Family  \
# Region
# Australia and New Zealand                        1.445060  1.529119
# Central Asia                                     0.786441  1.548969
# Eastern Asia                                     1.433627  1.384565
# Eastern Europe                                   1.312910  1.463485
# Latin America and the Caribbean                  1.079964  1.317385
#
#                                  Health..Life.Expectancy.   Freedom  \
# Region
# Australia and New Zealand                        0.830323  0.607835
# Central Asia                                     0.498273  0.658249
# Eastern Asia                                     0.793984  0.361467
# Eastern Europe                                   0.678500  0.420222
# Latin America and the Caribbean                  0.647587  0.488664
#
#                                  Generosity  Trust..Government.Corruption.  \
# Region
# Australia and New Zealand          0.488852                       0.342000
# Central Asia                       0.415984                       0.246528
# Eastern Asia                       0.258360                       0.063829
# Eastern Europe                     0.108845                       0.038339
# Latin America and the Caribbean    0.203399                       0.094663
#
#                                  Dystopia.Residual  country-code  region-code  \
# Region
# Australia and New Zealand                 2.055834    295.000000          9.0
# Central Asia                              1.816914    860.000000        142.0
# Eastern Asia                              2.126607    158.000000        142.0
# Eastern Europe                            2.138242    541.250000        150.0
# Latin America and the Caribbean           2.558736    338.071429         19.0
#
#                                  sub-region-code  intermediate-region-code
# Region
# Australia and New Zealand                   53.0                       NaN
# Central Asia                               143.0                       NaN
# Eastern Asia                                30.0                       NaN
# Eastern Europe                             151.0                       NaN
# Latin America and the Caribbean            419.0                 10.714286

# %% [markdown]
# * **Step 2: Explore and clean data for "Suicide Rates" and "Family Status" for the Top 50 Happiest Countries in the World:

# %%
# Study data files for suicide report 2017 for top 50 happiest countries
top_50_path = "../Suicide_Report/2017.csv"
suicide_rate_path = "../Suicide_Report/clean_suicide.csv"

# Read the mouse data and the study results
top_50 = pd.read_csv(top_50_path)
clean_suicide = pd.read_csv(suicide_rate_path)

# Combine the suicide report and happiness report into a single dataset 
merged_df = pd.merge(top_50, clean_suicide, on="Country")

# Display the data table for preview 
merged_df.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway             1.0             7.54          7.59         7.48
# 1      Denmark             2.0             7.52          7.58         7.46
# 2      Iceland             3.0             7.50          7.62         7.39
# 3  Switzerland             4.0             7.49          7.56         7.43
# 4      Finland             5.0             7.47          7.53         7.41
# 5  Netherlands             6.0             7.38          7.43         7.33
# 6       Canada             7.0             7.32          7.38         7.25
# 7  New Zealand             8.0             7.31          7.38         7.25
# 8       Sweden             9.0             7.28          7.34         7.22
# 9    Australia            10.0             7.28          7.36         7.21
#
#    Economy..GDP.per.Capita.  Family  Health..Life.Expectancy.  Freedom  \
# 0                      1.62    1.53                      0.80     0.64
# 1                      1.48    1.55                      0.79     0.63
# 2                      1.48    1.61                      0.83     0.63
# 3                      1.56    1.52                      0.86     0.62
# 4                      1.44    1.54                      0.81     0.62
# 5                      1.50    1.43                      0.81     0.59
# 6                      1.48    1.48                      0.83     0.61
# 7                      1.41    1.55                      0.82     0.61
# 8                      1.49    1.48                      0.83     0.61
# 9                      1.48    1.51                      0.84     0.60
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual Code  \
# 0        0.36                           0.32               2.28  NOR
# 1        0.36                           0.40               2.31  DNK
# 2        0.48                           0.15               2.32  ISL
# 3        0.29                           0.37               2.28  CHE
# 4        0.25                           0.38               2.43  FIN
# 5        0.47                           0.28               2.29  NLD
# 6        0.44                           0.29               2.19  CAN
# 7        0.50                           0.38               2.05  NZL
# 8        0.39                           0.38               2.10  SWE
# 9        0.48                           0.30               2.07  AUS
#
#    Death_rate
# 0        9.27
# 1        8.80
# 2        9.61
# 3        9.32
# 4       12.94
# 5        9.17
# 6       10.91
# 7       11.30
# 8       11.08
# 9       11.05

# %%
#Clean Up of data for specific analysis 

#Rename columns to add "Family" and "Suicide_Rate" and merge family and suicide rate into happiness report:
merged_df.columns = ['Country', 'Rank', 'Happy_Score', 'Top_Whisker','Low_Whisker','GDP','Family','Life','Freedom','Generosity','Trust_Gov','Dystopia','Country_Code','Suicide_Rate']
merged_df.head(10)

#Pull specific columns that will be used in analysis
clean_df = merged_df[['Rank','Country_Code','Country','Happy_Score','Family','Suicide_Rate']]

#To round and format values correctly in table
#clean_df["Rank"] = clean_df["Rank"].map("#{:.0f}".format)
#clean_df
clean_df.head(10)
# Out:
#    Rank Country_Code      Country  Happy_Score  Family  Suicide_Rate
# 0   1.0          NOR       Norway         7.54    1.53          9.27
# 1   2.0          DNK      Denmark         7.52    1.55          8.80
# 2   3.0          ISL      Iceland         7.50    1.61          9.61
# 3   4.0          CHE  Switzerland         7.49    1.52          9.32
# 4   5.0          FIN      Finland         7.47    1.54         12.94
# 5   6.0          NLD  Netherlands         7.38    1.43          9.17
# 6   7.0          CAN       Canada         7.32    1.48         10.91
# 7   8.0          NZL  New Zealand         7.31    1.55         11.30
# 8   9.0          SWE       Sweden         7.28    1.48         11.08
# 9  10.0          AUS    Australia         7.28    1.51         11.05

# %% [markdown]
# * **Step 3: Explore and clean data for "Life Expectancy" and "Population Size"

# %%
# Getting datas from Happiness Report for top 50 happiest countries and top 10 least happy countries, and populations & region data for these countries

# %%
# Merge happiness report, population and region data for the top 50 happy and top 10 least happy into one data set:

# %%
dataset2017=pd.read_csv('2017.csv')
datasetppl=pd.read_csv('POPULATION.csv')
datasetregion=pd.read_csv('region.csv')
dataset2017=dataset2017.iloc[0:50,:]
datasetleast=pd.read_csv('2017.csv')
datasetleast=datasetleast.iloc[145:155,:]

dataset2017 = pd.concat([dataset2017, datasetleast]).reset_index(drop=True)


dataset2017['region']="region"
dataset2017['population']="population"

for i in range(0,60):
    print(i)
    if i==32:
        continue
    if i==39:
        continue
    if i==48:
        continue
    if i==49:
        continue
    if i==50:
        continue
    if i==51:
        continue
    if i==56:
        continue
    
    country=dataset2017['Country'][i]
    index=datasetregion[datasetregion['Country'] ==country].index[0]
    dataset2017['region'][i]=datasetregion['Region'][index]
    indexppl=datasetppl[datasetppl['Country Name'] ==country].index[0]
    dataset2017['population'][i]=datasetppl['POPULATION'][index]

# %%
#importing the dataset to put top 50 happiest countries and top 10 least happy countries including population and region into one dataset:
dataset2017=pd.read_csv('FINAL.csv')
dataset2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual  \
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182
#
#            region  Population
# 0  Western Europe     5276968
# 1  Western Europe     5764980
# 2  Western Europe      343400
# 3  Western Europe     8451840
# 4  Western Europe     5508214

# %%
# Finally, we used the same dataset to analyze government trust and freedom.
